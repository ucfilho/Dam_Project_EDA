# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Dam_Project_EDA/blob/master/EDA_02_campo_E6_nov_25_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# carrega bibliotecas principais
import numpy as np
import pandas as pd
from pandas import read_excel
from numpy import loadtxt
import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
import pandas_profiling as pp
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !git clone https://github.com/ucfilho/Dam_Project_Methods #clonar do Github
# %cd Dam_Project_Methods
import Go2Confusion
# Out:
# fatal: destination path 'Dam_Project_Methods' already exists and is not an empty directory.
# /content/Dam_Project_Methods

# %%
# clicar no botao e selecionar o arquivo
from google.colab import files
def getLocalFiles():
    _files = files.upload()
    if len(_files) >0:
       for k,v in _files.items():
         open(k,'wb').write(v)
getLocalFiles()
# Out:
#      <input type="file" id="files-efbc9c01-d915-48c5-bfb0-57ead84db421" name="files[]" multiple disabled />
#      <output id="result-efbc9c01-d915-48c5-bfb0-57ead84db421">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Planilha campo_E6.xlsx to Planilha campo_E6 (2).xlsx

# %%
my_sheet = 'parcelas'
file_name = 'Planilha campo_E6.xlsx' # name of your excel file
df = read_excel(file_name, sheet_name = my_sheet,header=1)

# %%
pp.ProfileReport(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %%
correlation_matrix=df.corr(method='pearson').round(2)
sns.heatmap(correlation_matrix)

# %%
correlation_matrix=df.corr(method='pearson').round(2)
sns.heatmap(correlation_matrix)

# %%
df.corr(method='kendall').round(2)
sns.heatmap(correlation_matrix)

# %%
df.corr(method='spearman').round(2)
sns.heatmap(correlation_matrix)

# %%
correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8f09e15a_0fd0_11ea_9ffc_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8f09e15a_0fd0_11ea_9ffc_0242ac1c0002row0_col1 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_8f09e15a_0fd0_11ea_9ffc_0242ac1c0002row0_col2 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_8f09e15a_0fd0_11ea_9ffc_0242ac1c0002row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8f09e15a_0fd0_11ea_9ffc_0242ac1c0002row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8f09e15a_0fd0_11ea_9ffc_0242ac1c0002row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8f09e15a_0fd0_11ea_9ffc_0242ac1c0002row0_col6 {
#             background-color:  #82a6fb;
#             color:  #000000;
# ...
